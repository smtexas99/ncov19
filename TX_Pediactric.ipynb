# %% [markdown]
# Overview:
# Tracking Pediatric Hospitalizations in the Top 5 Texas Metros based on TSA.
# <LI>Dallas/Ft. Worth
# <LI>Houston
# <LI>San Antonio
# <LI>Austin
# <LI>El Paso
# <BR>
#
# Data Source: Texas DSHS

# %%
# %run tx_hosp.py
# Out:
# TEXAS COVID-19 HOSPITALIZATIONS
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Process Started:        2022-01-14 18:32
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# Report Generated on:  2022-01-14 18:32
# Data Source: Texas DSHS
# Last Data Point:      01/13/2022
# ...
